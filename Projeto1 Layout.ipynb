# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# Pedro Villas Bôas Dias -
# Enegnharia 2A

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# Qual o acesso à internet e a televisão das pessoas do Acre comparando suas rendas e a área em que moram?

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import *
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\pedro\OneDrive\Documentos\1)INSPER\Semestres\2 SEMESTRE\CIÊNCIAS DOS DADOS\Projeto1\Projeto1-CD

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')

#Se usar o arquivo compactado como está no dropbox público
dados2015 = pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')
dados2014 = pd.read_csv('DOM2014csv.zip', compression='zip', header=0, sep=',', quotechar='"')
dados2013 = pd.read_csv('DOM2013csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
At2015 = dados2015.loc[dados2015.UF== 12,['UF','V0219', 'V0226', 'V02322','V4105','V4621' ,'V4622',]]
At2014 = dados2014.loc[dados2014.UF== 12,['UF','V0219', 'V0226', 'V02322','V4105','V4621' ,'V4622',]]
At2013 = dados2013.loc[dados2013.UF==12,['UF','V0219', 'V0226', 'V02322','V4105','V4621' ,'V4622',]]

# %%
At2015.columns = ["Estado","Fonte_de_Iluminação","Tem_TV", "Acesso_Internet", "Moardia_Rural_Urbana", "Renda_per_capta_domiciliar",'Rendimento_per_capta_domiciliar']
At2014.columns = ["Estado","Fonte_de_Iluminação","Tem_TV", "Acesso_Internet", "Moardia_Rural_Urbana", "Renda_per_capta_domiciliar",'Rendimento_per_capta_domiciliar']
At2013.columns = ["Estado","Fonte_de_Iluminação","Tem_TV", "Acesso_Internet", "Moardia_Rural_Urbana", "Renda_per_capta_domiciliar",'Rendimento_per_capta_domiciliar']

# %%
At2015.columns
At2014.columns
At2013.columns
# Out:
# Index(['Estado', 'Fonte_de_Iluminação', 'Tem_TV', 'Acesso_Internet',
#        'Moardia_Rural_Urbana', 'Renda_per_capta_domiciliar',
#        'Rendimento_per_capta_domiciliar'],
#       dtype='object')

# %%
At2015.Estado = At2015.Estado.astype('category')
At2015.Fonte_de_Iluminação = At2015.Fonte_de_Iluminação.astype('category')
At2015.Tem_TV = At2015.Tem_TV.astype('category')
At2015.Acesso_Internet = At2015.Acesso_Internet.astype('category')
At2015.Moardia_Rural_Urbana = At2015.Moardia_Rural_Urbana.astype('category')
At2015.Rendimento_per_capta_domiciliar = At2015.Rendimento_per_capta_domiciliar.astype('category')
At2015.Renda_per_capta_domiciliar = At2015.Renda_per_capta_domiciliar.astype('float')

# %%
At2014.Estado = At2014.Estado.astype('category')
At2014.Fonte_de_Iluminação = At2014.Fonte_de_Iluminação.astype('category')
At2014.Tem_TV = At2014.Tem_TV.astype('category')
At2014.Acesso_Internet = At2014.Acesso_Internet.astype('category')
At2014.Moardia_Rural_Urbana = At2014.Moardia_Rural_Urbana.astype('category')
At2014.Rendimento_per_capta_domiciliar = At2014.Rendimento_per_capta_domiciliar.astype('category')
At2014.Renda_per_capta_domiciliar = At2014.Renda_per_capta_domiciliar.astype('float')

# %%
At2013.Estado = At2013.Estado.astype('category')
At2013.Fonte_de_Iluminação = At2013.Fonte_de_Iluminação.astype('category')
At2013.Tem_TV = At2013.Tem_TV.astype('category')
At2013.Acesso_Internet = At2013.Acesso_Internet.astype('category')
At2013.Moardia_Rural_Urbana = At2013.Moardia_Rural_Urbana.astype('category')
At2013.Rendimento_per_capta_domiciliar = At2013.Rendimento_per_capta_domiciliar.astype('category')
At2013.Renda_per_capta_domiciliar = At2013.Renda_per_capta_domiciliar.astype('float')

# %%
At2015.Estado.cat.categories
At2014.Estado.cat.categories
At2013.Estado.cat.categories
# Out:
# Int64Index([12], dtype='int64')

# %%
At2015.Estado.cat.categories = (["Acre"])

At2015.Rendimento_per_capta_domiciliar.cat.categories  = (["Sem rendimento", "Até ¼ salário mínimo", "Mais de ¼ até ½ salário mínimo", "Mais de ½ até 1 salário mínimo", "Mais de 1 até  2 salários mínimos",\
"Mais de  2 até  3 salários mínimos", "Mais de 3 até 5 salários mínimos", "Mais de 5 salários mínimos", "Sem declaração"])

At2015.Fonte_de_Iluminação.cat.categories = (["Elétrica (de rede, gerador, solar)","Óleo, querosene ou gás de botijão", "Outra forma"])

At2015.Tem_TV.cat.categories = (["Sim","Não"])

At2015.Acesso_Internet.cat.categories = (["Sim","Não"])

At2015.Moardia_Rural_Urbana.cat.categories = (["URBANA - Cidade ou vila, área urbanizada","URBANA - Cidade ou vila, área não urbanizada",\
"RURAL - Aglomerado rural, isolado, povoado", "RURAL - Zona rural exclusive aglomerado rural"])

# %%
At2014.Estado.cat.categories = (["Acre"])

At2014.Rendimento_per_capta_domiciliar.cat.categories  = (["Sem rendimento", "Até ¼ salário mínimo", "Mais de ¼ até ½ salário mínimo", "Mais de ½ até 1 salário mínimo", "Mais de 1 até  2 salários mínimos",\
"Mais de  2 até  3 salários mínimos", "Mais de 3 até 5 salários mínimos", "Mais de 5 salários mínimos", "Sem declaração"])

At2014.Fonte_de_Iluminação.cat.categories = (["Elétrica (de rede, gerador, solar)","Óleo, querosene ou gás de botijão", "Outra forma"])

At2014.Tem_TV.cat.categories = (["Sim","Não"])

At2014.Acesso_Internet.cat.categories = (["Sim","Não"])

At2014.Moardia_Rural_Urbana.cat.categories = (["URBANA - Cidade ou vila, área urbanizada","URBANA - Cidade ou vila, área não urbanizada",\
"RURAL - Aglomerado rural, isolado, povoado", "RURAL - Zona rural exclusive aglomerado rural"])

# %%
At2013.Estado.cat.categories = (["Acre"])

At2013.Rendimento_per_capta_domiciliar.cat.categories  = (["Sem rendimento", "Até ¼ salário mínimo", "Mais de ¼ até ½ salário mínimo", "Mais de ½ até 1 salário mínimo", "Mais de 1 até  2 salários mínimos",\
"Mais de  2 até  3 salários mínimos", "Mais de 3 até 5 salários mínimos", "Mais de 5 salários mínimos", "Sem declaração"])

At2013.Fonte_de_Iluminação.cat.categories = (["Elétrica (de rede, gerador, solar)","Óleo, querosene ou gás de botijão", "Outra forma"])

At2013.Tem_TV.cat.categories = (["Sim","Não"])

At2013.Acesso_Internet.cat.categories = (["Sim","Não"])

At2013.Moardia_Rural_Urbana.cat.categories = (["URBANA - Cidade ou vila, área urbanizada","URBANA - Cidade ou vila, área não urbanizada",\
"RURAL - Aglomerado rural, isolado, povoado", "RURAL - Zona rural exclusive aglomerado rural"])

# %%
At2015 = At2015.dropna() 
At2014 = At2014.dropna() 
At2013 = At2013.dropna()

# %%
At2015
# Out:
#      Estado                 Fonte_de_Iluminação Tem_TV Acesso_Internet  \
# 2837   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2838   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2839   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2840   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2841   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 2842   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2843   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2844   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2845   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2847   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2848   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2849   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 2850   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2851   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2852   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2853   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2854   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2855   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2858   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2860   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 2861   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2862   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2864   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2866   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2867   Acre  Elétrica (de rede, gerador, solar)    Não             Sim
# 2869   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2870   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2872   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2873   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2875   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# ...     ...                                 ...    ...             ...
# 4447   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4448   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4449   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4450   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4451   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4452   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4453   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4454   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4455   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4456   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4457   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4458   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4459   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4460   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4461   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4462   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4463   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4465   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4466   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 4467   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4468   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 4469   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 4470   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4471   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4472   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4473   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4474   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 4476   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4477   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 4478   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
#
#                                Moardia_Rural_Urbana  \
# 2837       URBANA - Cidade ou vila, área urbanizada
# 2838       URBANA - Cidade ou vila, área urbanizada
# 2839       URBANA - Cidade ou vila, área urbanizada
# 2840       URBANA - Cidade ou vila, área urbanizada
# 2841       URBANA - Cidade ou vila, área urbanizada
# 2842       URBANA - Cidade ou vila, área urbanizada
# 2843       URBANA - Cidade ou vila, área urbanizada
# 2844       URBANA - Cidade ou vila, área urbanizada
# 2845       URBANA - Cidade ou vila, área urbanizada
# 2847       URBANA - Cidade ou vila, área urbanizada
# 2848       URBANA - Cidade ou vila, área urbanizada
# 2849       URBANA - Cidade ou vila, área urbanizada
# 2850       URBANA - Cidade ou vila, área urbanizada
# 2851       URBANA - Cidade ou vila, área urbanizada
# 2852       URBANA - Cidade ou vila, área urbanizada
# 2853       URBANA - Cidade ou vila, área urbanizada
# 2854       URBANA - Cidade ou vila, área urbanizada
# 2855       URBANA - Cidade ou vila, área urbanizada
# 2858       URBANA - Cidade ou vila, área urbanizada
# 2860       URBANA - Cidade ou vila, área urbanizada
# 2861       URBANA - Cidade ou vila, área urbanizada
# 2862       URBANA - Cidade ou vila, área urbanizada
# 2864       URBANA - Cidade ou vila, área urbanizada
# 2866       URBANA - Cidade ou vila, área urbanizada
# 2867       URBANA - Cidade ou vila, área urbanizada
# 2869       URBANA - Cidade ou vila, área urbanizada
# 2870       URBANA - Cidade ou vila, área urbanizada
# 2872       URBANA - Cidade ou vila, área urbanizada
# 2873       URBANA - Cidade ou vila, área urbanizada
# 2875  RURAL - Zona rural exclusive aglomerado rural
# ...                                             ...
# 4447  RURAL - Zona rural exclusive aglomerado rural
# 4448  RURAL - Zona rural exclusive aglomerado rural
# 4449  RURAL - Zona rural exclusive aglomerado rural
# 4450  RURAL - Zona rural exclusive aglomerado rural
# 4451  RURAL - Zona rural exclusive aglomerado rural
# 4452  RURAL - Zona rural exclusive aglomerado rural
# 4453  RURAL - Zona rural exclusive aglomerado rural
# 4454  RURAL - Zona rural exclusive aglomerado rural
# 4455  RURAL - Zona rural exclusive aglomerado rural
# 4456  RURAL - Zona rural exclusive aglomerado rural
# 4457  RURAL - Zona rural exclusive aglomerado rural
# 4458  RURAL - Zona rural exclusive aglomerado rural
# 4459  RURAL - Zona rural exclusive aglomerado rural
# 4460  RURAL - Zona rural exclusive aglomerado rural
# 4461  RURAL - Zona rural exclusive aglomerado rural
# 4462  RURAL - Zona rural exclusive aglomerado rural
# 4463     RURAL - Aglomerado rural, isolado, povoado
# 4465     RURAL - Aglomerado rural, isolado, povoado
# 4466     RURAL - Aglomerado rural, isolado, povoado
# 4467     RURAL - Aglomerado rural, isolado, povoado
# 4468     RURAL - Aglomerado rural, isolado, povoado
# 4469     RURAL - Aglomerado rural, isolado, povoado
# 4470     RURAL - Aglomerado rural, isolado, povoado
# 4471     RURAL - Aglomerado rural, isolado, povoado
# 4472     RURAL - Aglomerado rural, isolado, povoado
# 4473     RURAL - Aglomerado rural, isolado, povoado
# 4474     RURAL - Aglomerado rural, isolado, povoado
# 4476     RURAL - Aglomerado rural, isolado, povoado
# 4477     RURAL - Aglomerado rural, isolado, povoado
# 4478     RURAL - Aglomerado rural, isolado, povoado
#
#       Renda_per_capta_domiciliar     Rendimento_per_capta_domiciliar
# 2837                       500.0      Mais de ½ até 1 salário mínimo
# 2838                      1025.0   Mais de 1 até  2 salários mínimos
# 2839                       500.0      Mais de ½ até 1 salário mínimo
# 2840                       209.0      Mais de ¼ até ½ salário mínimo
# 2841                      1576.0   Mais de 1 até  2 salários mínimos
# 2842                       788.0      Mais de ½ até 1 salário mínimo
# 2843                      1576.0   Mais de 1 até  2 salários mínimos
# 2844                      1500.0   Mais de 1 até  2 salários mínimos
# 2845                      1000.0   Mais de 1 até  2 salários mínimos
# 2847                     11500.0          Mais de 5 salários mínimos
# 2848                       750.0      Mais de ½ até 1 salário mínimo
# 2849                       207.0      Mais de ¼ até ½ salário mínimo
# 2850                       970.0   Mais de 1 até  2 salários mínimos
# 2851                      3650.0    Mais de 3 até 5 salários mínimos
# 2852                       250.0      Mais de ¼ até ½ salário mínimo
# 2853                       220.0      Mais de ¼ até ½ salário mínimo
# 2854                      1068.0   Mais de 1 até  2 salários mínimos
# 2855                       611.0      Mais de ½ até 1 salário mínimo
# 2858                       883.0   Mais de 1 até  2 salários mínimos
# 2860                       788.0      Mais de ½ até 1 salário mínimo
# 2861                       500.0      Mais de ½ até 1 salário mínimo
# 2862                       393.0      Mais de ¼ até ½ salário mínimo
# 2864                       262.0      Mais de ¼ até ½ salário mínimo
# 2866                       500.0      Mais de ½ até 1 salário mínimo
# 2867                       187.0                Até ¼ salário mínimo
# 2869                       357.0      Mais de ¼ até ½ salário mínimo
# 2870                       757.0      Mais de ½ até 1 salário mínimo
# 2872                       437.0      Mais de ½ até 1 salário mínimo
# 2873                       211.0      Mais de ¼ até ½ salário mínimo
# 2875                      4062.0          Mais de 5 salários mínimos
# ...                          ...                                 ...
# 4447                       378.0      Mais de ¼ até ½ salário mínimo
# 4448                       266.0      Mais de ¼ até ½ salário mínimo
# 4449                       193.0                Até ¼ salário mínimo
# 4450                       635.0      Mais de ½ até 1 salário mínimo
# 4451                       600.0      Mais de ½ até 1 salário mínimo
# 4452                       350.0      Mais de ¼ até ½ salário mínimo
# 4453                      2358.0  Mais de  2 até  3 salários mínimos
# 4454                       394.0      Mais de ¼ até ½ salário mínimo
# 4455                       239.0      Mais de ¼ até ½ salário mínimo
# 4456                       950.0   Mais de 1 até  2 salários mínimos
# 4457                       700.0      Mais de ½ até 1 salário mínimo
# 4458                       680.0      Mais de ½ até 1 salário mínimo
# 4459                       519.0      Mais de ½ até 1 salário mínimo
# 4460                       337.0      Mais de ¼ até ½ salário mínimo
# 4461                       290.0      Mais de ¼ até ½ salário mínimo
# 4462                       400.0      Mais de ½ até 1 salário mínimo
# 4463                       429.0      Mais de ½ até 1 salário mínimo
# 4465                       459.0      Mais de ½ até 1 salário mínimo
# 4466                      1200.0   Mais de 1 até  2 salários mínimos
# 4467                      1200.0   Mais de 1 até  2 salários mínimos
# 4468                      1500.0   Mais de 1 até  2 salários mínimos
# 4469                       490.0      Mais de ½ até 1 salário mínimo
# 4470                       262.0      Mais de ¼ até ½ salário mínimo
# 4471                       586.0      Mais de ½ até 1 salário mínimo
# 4472                       150.0                Até ¼ salário mínimo
# 4473                       213.0      Mais de ¼ até ½ salário mínimo
# 4474                        57.0                Até ¼ salário mínimo
# 4476                       788.0      Mais de ½ até 1 salário mínimo
# 4477                      1228.0   Mais de 1 até  2 salários mínimos
# 4478                      1144.0   Mais de 1 até  2 salários mínimos
#
# [1321 rows x 7 columns]

# %%
At2015.to_excel("Dados2015.xlsx")
At2014.to_excel("Dados2014.xlsx")
At2013.to_excel("Dados2013.xlsx")

# %% [markdown]
# # 2015

# %% [markdown]
# # Moradia

# %%
Moradia_Internet2015=pd.crosstab( At2015.Moardia_Rural_Urbana, At2015.Acesso_Internet, margins=True, rownames=['Moardia (Área Rural ou Urbana)'], colnames=['Acesso Internet'], normalize=True)*100
Moradia_Internet2015=Moradia_Internet2015.round(decimals=1)
Moradia_Internet2015
# Out:
# Acesso Internet                                 Sim   Não    All
# Moardia (Área Rural ou Urbana)
# URBANA - Cidade ou vila, área urbanizada       39.9  29.9   69.8
# URBANA - Cidade ou vila, área não urbanizada    2.0   1.7    3.6
# RURAL - Aglomerado rural, isolado, povoado      1.7   1.6    3.3
# RURAL - Zona rural exclusive aglomerado rural   2.5  20.8   23.3
# All                                            46.0  54.0  100.0

# %%
plot = Moradia_Internet2015.plot(kind='bar')
plt.ylabel('Freq.Relativa (em %)')

# %%
Moradia_TV2015=pd.crosstab( At2015.Moardia_Rural_Urbana, At2015.Tem_TV, margins=True, rownames=['Moardia (Área Rural ou Urbana)'], colnames=['Tem Tv'], normalize=True)*100
Moradia_TV2015=Moradia_TV2015.round(decimals=1)
Moradia_TV2015
# Out:
# Tem Tv                                          Sim  Não    All
# Moardia (Área Rural ou Urbana)
# URBANA - Cidade ou vila, área urbanizada       66.2  3.6   69.8
# URBANA - Cidade ou vila, área não urbanizada    3.6  0.1    3.6
# RURAL - Aglomerado rural, isolado, povoado      2.8  0.5    3.3
# RURAL - Zona rural exclusive aglomerado rural  17.9  5.4   23.3
# All                                            90.5  9.5  100.0

# %%
plot = Moradia_TV2015.plot(kind='bar')
plt.ylabel('Freq.Relativa (em %)')

# %% [markdown]
# # Renda

# %%
ren2015 = At2015.Renda_per_capta_domiciliar
ren2015.describe()
# Out:
# count    1.321000e+03
# mean     1.362604e+10
# std      1.159765e+11
# min      0.000000e+00
# 25%      2.800000e+02
# 50%      5.250000e+02
# 75%      1.000000e+03
# max      1.000000e+12
# Name: Renda_per_capta_domiciliar, dtype: float64

# %% [markdown]
# Utilizando o conceito de amplitude interquartil, definimos que ualquer vaolor que não esteja no intervalo [Q1 - 1,5Q: Q3 + 1,5Q] sendo Q = Q3 - Q1, Q3 (Terceiro Quartil) e Q1 (Primeiro Quartil), ou seja [-800:2080] seria extremo.

# %%
faixa = (0,937/4 ,937/2, 937, 937*2,2080)
ren2015rel = pd.cut(ren2015, faixa, False)
print('Frequências relativas:')
ut1 = (ren2015rel.value_counts(sort=False, normalize=True)*100).round(decimals=1)
print(ut1,'\n')
# Out:
# Frequências relativas:
# [0.0, 234.25)       19.8
# [234.25, 468.5)     29.1
# [468.5, 937.0)      30.2
# [937.0, 1874.0)     19.5
# [1874.0, 2080.0)     1.4
# Name: Renda_per_capta_domiciliar, dtype: float64

# %%
fig = plt.figure(figsize=(11, 5))
plt.subplot(121)
plot = ren2015.plot.hist(bins=faixa,title='Renda percapta domiciliar', figsize=(6, 6), normed=1, alpha=0.5)
plt.ylabel('Densidade')
plt.xlabel('renda (em reais)')

plt.subplot(122)
plot = ren2015.plot.hist(bins=faixa, title='Renda percapta domiciliar', weights=zeros_like(ren2015)+1./ren2015.size*100, figsize=(6, 6), color = ('g'), alpha=0.5)
plt.ylabel('Frequência Relativa')
plt.xlabel('renda (em reais)')

plt.tight_layout()
plt.show()

# %%
renda_Internet2015=pd.crosstab( ren2015rel, At2015.Acesso_Internet, margins=True, rownames=['Renda per capta domiciliar (em salários mínimos)'], colnames=['Acesso Internet'], normalize=True)*100
renda_Internet2015=renda_Internet2015.round(decimals=1)
renda_Internet2015
# Out:
# Acesso Internet                                    Sim   Não    All
# Renda per capta domiciliar (em salários mínimos)
# [0.0, 234.25)                                      4.3  15.5   19.8
# [234.25, 468.5)                                   11.9  17.2   29.1
# [468.5, 937.0)                                    14.9  15.3   30.2
# [937.0, 1874.0)                                   11.6   7.9   19.5
# [1874.0, 2080.0)                                   1.0   0.4    1.4
# All                                               43.7  56.3  100.0

# %%
plot = renda_Internet2015.plot(kind='bar')
plt.ylabel('Freq.Relativa (em %)')

# %%
renda_TV2015=pd.crosstab( ren2015rel, At2015.Tem_TV, margins=True, rownames=['Renda per capta domiciliar (em salários mínimos)'], colnames=['Tem Tv'], normalize=True)*100
renda_TV2015=renda_TV2015.round(decimals=1)
renda_TV2015
# Out:
# Tem Tv                                             Sim  Não    All
# Renda per capta domiciliar (em salários mínimos)
# [0.0, 234.25)                                     16.4  3.4   19.8
# [234.25, 468.5)                                   26.4  2.7   29.1
# [468.5, 937.0)                                    27.8  2.4   30.2
# [937.0, 1874.0)                                   18.2  1.2   19.5
# [1874.0, 2080.0)                                   1.3  0.1    1.4
# All                                               90.2  9.8  100.0

# %%
plot = renda_TV2015.plot(kind='bar')
plt.ylabel('Freq.Relativa (em %)')

# %% [markdown]
# # 2014

# %%
At2014
# Out:
#      Estado                 Fonte_de_Iluminação Tem_TV Acesso_Internet  \
# 2856   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2857   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2858   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2863   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2864   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2865   Acre  Elétrica (de rede, gerador, solar)    Não             Sim
# 2866   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2867   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2868   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2869   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2870   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2871   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2872   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2873   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2874   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2876   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2878   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2879   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2880   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2881   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2882   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2883   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2884   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2885   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2887   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 2888   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2889   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2890   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2891   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2892   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# ...     ...                                 ...    ...             ...
# 4448   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4449   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4451   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4452   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4454   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4455   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4456   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4457   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4458   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4459   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4460   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4461   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4463   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4464   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4466   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4467   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4469   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4470   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4471   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4472   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 4473   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4475   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4476   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4477   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4478   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4479   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 4480   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 4481   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 4482   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 4483   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
#
#                                Moardia_Rural_Urbana  \
# 2856       URBANA - Cidade ou vila, área urbanizada
# 2857       URBANA - Cidade ou vila, área urbanizada
# 2858       URBANA - Cidade ou vila, área urbanizada
# 2863       URBANA - Cidade ou vila, área urbanizada
# 2864       URBANA - Cidade ou vila, área urbanizada
# 2865       URBANA - Cidade ou vila, área urbanizada
# 2866       URBANA - Cidade ou vila, área urbanizada
# 2867       URBANA - Cidade ou vila, área urbanizada
# 2868       URBANA - Cidade ou vila, área urbanizada
# 2869       URBANA - Cidade ou vila, área urbanizada
# 2870       URBANA - Cidade ou vila, área urbanizada
# 2871       URBANA - Cidade ou vila, área urbanizada
# 2872       URBANA - Cidade ou vila, área urbanizada
# 2873       URBANA - Cidade ou vila, área urbanizada
# 2874       URBANA - Cidade ou vila, área urbanizada
# 2876       URBANA - Cidade ou vila, área urbanizada
# 2878       URBANA - Cidade ou vila, área urbanizada
# 2879       URBANA - Cidade ou vila, área urbanizada
# 2880       URBANA - Cidade ou vila, área urbanizada
# 2881       URBANA - Cidade ou vila, área urbanizada
# 2882       URBANA - Cidade ou vila, área urbanizada
# 2883       URBANA - Cidade ou vila, área urbanizada
# 2884       URBANA - Cidade ou vila, área urbanizada
# 2885       URBANA - Cidade ou vila, área urbanizada
# 2887       URBANA - Cidade ou vila, área urbanizada
# 2888       URBANA - Cidade ou vila, área urbanizada
# 2889       URBANA - Cidade ou vila, área urbanizada
# 2890       URBANA - Cidade ou vila, área urbanizada
# 2891       URBANA - Cidade ou vila, área urbanizada
# 2892       URBANA - Cidade ou vila, área urbanizada
# ...                                             ...
# 4448     RURAL - Aglomerado rural, isolado, povoado
# 4449     RURAL - Aglomerado rural, isolado, povoado
# 4451  RURAL - Zona rural exclusive aglomerado rural
# 4452  RURAL - Zona rural exclusive aglomerado rural
# 4454  RURAL - Zona rural exclusive aglomerado rural
# 4455  RURAL - Zona rural exclusive aglomerado rural
# 4456  RURAL - Zona rural exclusive aglomerado rural
# 4457  RURAL - Zona rural exclusive aglomerado rural
# 4458  RURAL - Zona rural exclusive aglomerado rural
# 4459  RURAL - Zona rural exclusive aglomerado rural
# 4460  RURAL - Zona rural exclusive aglomerado rural
# 4461  RURAL - Zona rural exclusive aglomerado rural
# 4463  RURAL - Zona rural exclusive aglomerado rural
# 4464  RURAL - Zona rural exclusive aglomerado rural
# 4466  RURAL - Zona rural exclusive aglomerado rural
# 4467  RURAL - Zona rural exclusive aglomerado rural
# 4469     RURAL - Aglomerado rural, isolado, povoado
# 4470     RURAL - Aglomerado rural, isolado, povoado
# 4471     RURAL - Aglomerado rural, isolado, povoado
# 4472     RURAL - Aglomerado rural, isolado, povoado
# 4473     RURAL - Aglomerado rural, isolado, povoado
# 4475     RURAL - Aglomerado rural, isolado, povoado
# 4476     RURAL - Aglomerado rural, isolado, povoado
# 4477     RURAL - Aglomerado rural, isolado, povoado
# 4478     RURAL - Aglomerado rural, isolado, povoado
# 4479     RURAL - Aglomerado rural, isolado, povoado
# 4480     RURAL - Aglomerado rural, isolado, povoado
# 4481     RURAL - Aglomerado rural, isolado, povoado
# 4482     RURAL - Aglomerado rural, isolado, povoado
# 4483     RURAL - Aglomerado rural, isolado, povoado
#
#       Renda_per_capta_domiciliar     Rendimento_per_capta_domiciliar
# 2856                8.000000e+02   Mais de 1 até  2 salários mínimos
# 2857                1.000000e+02                Até ¼ salário mínimo
# 2858                3.660000e+02      Mais de ½ até 1 salário mínimo
# 2863                3.620000e+02      Mais de ¼ até ½ salário mínimo
# 2864                2.000000e+03  Mais de  2 até  3 salários mínimos
# 2865                2.241000e+03    Mais de 3 até 5 salários mínimos
# 2866                1.100000e+03   Mais de 1 até  2 salários mínimos
# 2867                5.000000e+02      Mais de ½ até 1 salário mínimo
# 2868                6.500000e+02      Mais de ½ até 1 salário mínimo
# 2869                4.000000e+03          Mais de 5 salários mínimos
# 2870                3.660000e+02      Mais de ½ até 1 salário mínimo
# 2871                1.000000e+03   Mais de 1 até  2 salários mínimos
# 2872                1.000000e+12                      Sem declaração
# 2873                5.330000e+02      Mais de ½ até 1 salário mínimo
# 2874                3.620000e+02      Mais de ¼ até ½ salário mínimo
# 2876                2.330000e+02      Mais de ¼ até ½ salário mínimo
# 2878                5.530000e+02      Mais de ½ até 1 salário mínimo
# 2879                6.000000e+02      Mais de ½ até 1 salário mínimo
# 2880                1.308000e+03   Mais de 1 até  2 salários mínimos
# 2881                3.520000e+02      Mais de ¼ até ½ salário mínimo
# 2882                1.125000e+03   Mais de 1 até  2 salários mínimos
# 2883                1.175000e+03   Mais de 1 até  2 salários mínimos
# 2884                4.080000e+02      Mais de ½ até 1 salário mínimo
# 2885                1.100000e+03   Mais de 1 até  2 salários mínimos
# 2887                2.810000e+02      Mais de ¼ até ½ salário mínimo
# 2888                1.810000e+02                Até ¼ salário mínimo
# 2889                3.620000e+02      Mais de ¼ até ½ salário mínimo
# 2890                1.300000e+03   Mais de 1 até  2 salários mínimos
# 2891                2.000000e+02      Mais de ¼ até ½ salário mínimo
# 2892                1.110000e+02                Até ¼ salário mínimo
# ...                          ...                                 ...
# 4448                7.240000e+02      Mais de ½ até 1 salário mínimo
# 4449                3.190000e+02      Mais de ¼ até ½ salário mínimo
# 4451                3.000000e+02      Mais de ¼ até ½ salário mínimo
# 4452                1.060000e+03   Mais de 1 até  2 salários mínimos
# 4454                3.000000e+02      Mais de ¼ até ½ salário mínimo
# 4455                5.490000e+02      Mais de ½ até 1 salário mínimo
# 4456                2.560000e+02      Mais de ¼ até ½ salário mínimo
# 4457                6.000000e+02      Mais de ½ até 1 salário mínimo
# 4458                2.900000e+02      Mais de ¼ até ½ salário mínimo
# 4459                6.920000e+02      Mais de ½ até 1 salário mínimo
# 4460                3.740000e+02      Mais de ½ até 1 salário mínimo
# 4461                6.470000e+02      Mais de ½ até 1 salário mínimo
# 4463                1.000000e+12                      Sem declaração
# 4464                1.000000e+12                      Sem declaração
# 4466                3.620000e+02      Mais de ¼ até ½ salário mínimo
# 4467                1.374000e+03   Mais de 1 até  2 salários mínimos
# 4469                5.700000e+01                Até ¼ salário mínimo
# 4470                3.620000e+02      Mais de ¼ até ½ salário mínimo
# 4471                2.800000e+01                Até ¼ salário mínimo
# 4472                2.670000e+02      Mais de ¼ até ½ salário mínimo
# 4473                7.240000e+02      Mais de ½ até 1 salário mínimo
# 4475                1.448000e+03   Mais de 1 até  2 salários mínimos
# 4476                7.240000e+02      Mais de ½ até 1 salário mínimo
# 4477                6.500000e+02      Mais de ½ até 1 salário mínimo
# 4478                1.200000e+03   Mais de 1 até  2 salários mínimos
# 4479                5.790000e+02      Mais de ½ até 1 salário mínimo
# 4480                5.000000e+02      Mais de ½ até 1 salário mínimo
# 4481                4.500000e+02      Mais de ½ até 1 salário mínimo
# 4482                6.000000e+02      Mais de ½ até 1 salário mínimo
# 4483                6.200000e+02      Mais de ½ até 1 salário mínimo
#
# [1326 rows x 7 columns]

# %% [markdown]
# # Moradia

# %%
Moradia_Internet2014=pd.crosstab( At2014.Moardia_Rural_Urbana, At2014.Acesso_Internet, margins=True, rownames=['Moardia (Área Rural ou Urbana)'], colnames=['Acesso Internet'], normalize=True)*100
Moradia_Internet2014=Moradia_Internet2014.round(decimals=1)
Moradia_Internet2014
# Out:
# Acesso Internet                                 Sim   Não    All
# Moardia (Área Rural ou Urbana)
# URBANA - Cidade ou vila, área urbanizada       37.4  34.5   71.9
# URBANA - Cidade ou vila, área não urbanizada    1.5   1.8    3.3
# RURAL - Aglomerado rural, isolado, povoado      1.1   2.1    3.2
# RURAL - Zona rural exclusive aglomerado rural   1.6  20.1   21.6
# All                                            41.6  58.4  100.0

# %%
plot = Moradia_Internet2014.plot(kind='bar')
plt.ylabel('Freq.Relativa (em %)')

# %%
Moradia_TV2014=pd.crosstab( At2014.Moardia_Rural_Urbana, At2014.Tem_TV, margins=True, rownames=['Moardia (Área Rural ou Urbana)'], colnames=['Tem TV'], normalize=True)*100
Moradia_TV2014=Moradia_TV2014.round(decimals=1)
Moradia_TV2014
# Out:
# Tem TV                                          Sim   Não    All
# Moardia (Área Rural ou Urbana)
# URBANA - Cidade ou vila, área urbanizada       68.7   3.2   71.9
# URBANA - Cidade ou vila, área não urbanizada    3.2   0.1    3.3
# RURAL - Aglomerado rural, isolado, povoado      2.7   0.5    3.2
# RURAL - Zona rural exclusive aglomerado rural  14.8   6.9   21.6
# All                                            89.4  10.6  100.0

# %%
plot = Moradia_TV2014.plot(kind='bar')
plt.ylabel('Freq.Relativa (em %)')

# %% [markdown]
# # Renda

# %%
ren2014 = At2014.Renda_per_capta_domiciliar
ren2014.describe()
# Out:
# count    1.326000e+03
# mean     1.432881e+10
# std      1.188871e+11
# min      0.000000e+00
# 25%      2.710000e+02
# 50%      5.240000e+02
# 75%      9.995000e+02
# max      1.000000e+12
# Name: Renda_per_capta_domiciliar, dtype: float64

# %% [markdown]
# Utilizando o conceito de amplitude interquartil, definimos que ualquer vaolor que não esteja no intervalo [Q1 - 1,5Q: Q3 + 1,5Q] sendo Q = Q3 - Q1, Q3 (Terceiro Quartil) e Q1 (Primeiro Quartil), ou seja [-821.75:2092.25] seria extremo.

# %%
faixa2 = (0,937/4 ,937/2, 937, 937*2,2092.25)
ren2014rel = pd.cut(ren2014, faixa2, False)
print('Frequências relativas:')
ut2 = (ren2014rel.value_counts(sort=False, normalize=True)*100).round(decimals=1)
print(ut2,'\n')
# Out:
# Frequências relativas:
# [0.0, 234.25)        21.0
# [234.25, 468.5)      29.0
# [468.5, 937.0)       31.3
# [937.0, 1874.0)      17.3
# [1874.0, 2092.25)     1.3
# Name: Renda_per_capta_domiciliar, dtype: float64

# %%
fig = plt.figure(figsize=(11, 5))
plt.subplot(121)
plot = ren2014.plot.hist(bins=faixa2,title='Renda percapta domiciliar', figsize=(6, 6), normed=1, alpha=0.5)
plt.ylabel('Densidade')
plt.xlabel('renda (em reais)')

plt.subplot(122)
plot = ren2014.plot.hist(bins=faixa2, title='Renda percapta domiciliar', weights=zeros_like(ren2014)+1./ren2014.size*100, figsize=(6, 6), color = ('g'), alpha=0.5)
plt.ylabel('Frequência Relativa')
plt.xlabel('renda (em reais)')

plt.tight_layout()
plt.show()

# %%
renda_Internet2014=pd.crosstab( ren2014rel, At2014.Acesso_Internet, margins=True, rownames=['Renda per capta domiciliar (em salários mínimos)'], colnames=['Acesso Internet'], normalize=True)*100
renda_Internet2014=renda_Internet2014.round(decimals=1)
renda_Internet2014
# Out:
# Acesso Internet                                    Sim   Não    All
# Renda per capta domiciliar (em salários mínimos)
# [0.0, 234.25)                                      3.8  17.2   21.0
# [234.25, 468.5)                                    9.9  19.1   29.0
# [468.5, 937.0)                                    13.2  18.1   31.3
# [937.0, 1874.0)                                   10.5   6.8   17.3
# [1874.0, 2092.25)                                  0.8   0.5    1.3
# All                                               38.3  61.7  100.0

# %%
plot = renda_Internet2014.plot(kind='bar')
plt.ylabel('Freq.Relativa (em %)')

# %%
renda_TV2014=pd.crosstab( ren2014rel, At2014.Tem_TV, margins=True, rownames=['Renda per capta domiciliar (em salários mínimos)'], colnames=['Tem Tv'], normalize=True)*100
renda_TV2014=renda_TV2014.round(decimals=1)
renda_TV2014
# Out:
# Tem Tv                                             Sim   Não    All
# Renda per capta domiciliar (em salários mínimos)
# [0.0, 234.25)                                     16.3   4.7   21.0
# [234.25, 468.5)                                   25.9   3.1   29.0
# [468.5, 937.0)                                    29.2   2.2   31.3
# [937.0, 1874.0)                                   16.3   1.0   17.3
# [1874.0, 2092.25)                                  1.2   0.2    1.3
# All                                               88.9  11.1  100.0

# %%
plot = renda_TV2014.plot(kind='bar')
plt.ylabel('Freq.Relativa (em %)')

# %% [markdown]
# # 2013

# %%
At2013
# Out:
#      Estado                 Fonte_de_Iluminação Tem_TV Acesso_Internet  \
# 2836   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2837   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2838   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2839   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2840   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2842   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2843   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2844   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2847   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 2848   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2850   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2852   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2853   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2854   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2855   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 2856   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2857   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2859   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2860   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2862   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2864   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2866   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2867   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2868   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2869   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2870   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2872   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2875   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2876   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 2877   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# ...     ...                                 ...    ...             ...
# 4360   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4361   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4362   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4363   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4365   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4366   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4367   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4368   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4369   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4370   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4371   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4372   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4373   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4374   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4375   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4376   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4377   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4379   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4381   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4382   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4383   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4385   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4386   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4387   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4388   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4389   Acre  Elétrica (de rede, gerador, solar)    Sim             Sim
# 4390   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4391   Acre  Elétrica (de rede, gerador, solar)    Não             Não
# 4392   Acre  Elétrica (de rede, gerador, solar)    Sim             Não
# 4393   Acre  Elétrica (de rede, gerador, solar)    Não             Não
#
#                                Moardia_Rural_Urbana  \
# 2836       URBANA - Cidade ou vila, área urbanizada
# 2837       URBANA - Cidade ou vila, área urbanizada
# 2838       URBANA - Cidade ou vila, área urbanizada
# 2839       URBANA - Cidade ou vila, área urbanizada
# 2840       URBANA - Cidade ou vila, área urbanizada
# 2842       URBANA - Cidade ou vila, área urbanizada
# 2843       URBANA - Cidade ou vila, área urbanizada
# 2844       URBANA - Cidade ou vila, área urbanizada
# 2847       URBANA - Cidade ou vila, área urbanizada
# 2848       URBANA - Cidade ou vila, área urbanizada
# 2850       URBANA - Cidade ou vila, área urbanizada
# 2852       URBANA - Cidade ou vila, área urbanizada
# 2853       URBANA - Cidade ou vila, área urbanizada
# 2854       URBANA - Cidade ou vila, área urbanizada
# 2855       URBANA - Cidade ou vila, área urbanizada
# 2856       URBANA - Cidade ou vila, área urbanizada
# 2857       URBANA - Cidade ou vila, área urbanizada
# 2859       URBANA - Cidade ou vila, área urbanizada
# 2860       URBANA - Cidade ou vila, área urbanizada
# 2862       URBANA - Cidade ou vila, área urbanizada
# 2864       URBANA - Cidade ou vila, área urbanizada
# 2866       URBANA - Cidade ou vila, área urbanizada
# 2867       URBANA - Cidade ou vila, área urbanizada
# 2868  RURAL - Zona rural exclusive aglomerado rural
# 2869  RURAL - Zona rural exclusive aglomerado rural
# 2870  RURAL - Zona rural exclusive aglomerado rural
# 2872  RURAL - Zona rural exclusive aglomerado rural
# 2875  RURAL - Zona rural exclusive aglomerado rural
# 2876  RURAL - Zona rural exclusive aglomerado rural
# 2877  RURAL - Zona rural exclusive aglomerado rural
# ...                                             ...
# 4360  RURAL - Zona rural exclusive aglomerado rural
# 4361  RURAL - Zona rural exclusive aglomerado rural
# 4362  RURAL - Zona rural exclusive aglomerado rural
# 4363  RURAL - Zona rural exclusive aglomerado rural
# 4365  RURAL - Zona rural exclusive aglomerado rural
# 4366  RURAL - Zona rural exclusive aglomerado rural
# 4367  RURAL - Zona rural exclusive aglomerado rural
# 4368  RURAL - Zona rural exclusive aglomerado rural
# 4369  RURAL - Zona rural exclusive aglomerado rural
# 4370  RURAL - Zona rural exclusive aglomerado rural
# 4371  RURAL - Zona rural exclusive aglomerado rural
# 4372  RURAL - Zona rural exclusive aglomerado rural
# 4373  RURAL - Zona rural exclusive aglomerado rural
# 4374  RURAL - Zona rural exclusive aglomerado rural
# 4375  RURAL - Zona rural exclusive aglomerado rural
# 4376  RURAL - Zona rural exclusive aglomerado rural
# 4377  RURAL - Zona rural exclusive aglomerado rural
# 4379     RURAL - Aglomerado rural, isolado, povoado
# 4381     RURAL - Aglomerado rural, isolado, povoado
# 4382     RURAL - Aglomerado rural, isolado, povoado
# 4383     RURAL - Aglomerado rural, isolado, povoado
# 4385     RURAL - Aglomerado rural, isolado, povoado
# 4386     RURAL - Aglomerado rural, isolado, povoado
# 4387     RURAL - Aglomerado rural, isolado, povoado
# 4388     RURAL - Aglomerado rural, isolado, povoado
# 4389     RURAL - Aglomerado rural, isolado, povoado
# 4390     RURAL - Aglomerado rural, isolado, povoado
# 4391     RURAL - Aglomerado rural, isolado, povoado
# 4392     RURAL - Aglomerado rural, isolado, povoado
# 4393     RURAL - Aglomerado rural, isolado, povoado
#
#       Renda_per_capta_domiciliar     Rendimento_per_capta_domiciliar
# 2836                3.390000e+02      Mais de ¼ até ½ salário mínimo
# 2837                4.080000e+02      Mais de ½ até 1 salário mínimo
# 2838                3.760000e+02      Mais de ½ até 1 salário mínimo
# 2839                3.760000e+03          Mais de 5 salários mínimos
# 2840                3.390000e+02      Mais de ¼ até ½ salário mínimo
# 2842                2.250000e+02      Mais de ¼ até ½ salário mínimo
# 2843                7.000000e+02   Mais de 1 até  2 salários mínimos
# 2844                2.296000e+03    Mais de 3 até 5 salários mínimos
# 2847                1.150000e+03   Mais de 1 até  2 salários mínimos
# 2848                1.800000e+02      Mais de ¼ até ½ salário mínimo
# 2850                2.900000e+03    Mais de 3 até 5 salários mínimos
# 2852                5.920000e+02      Mais de ½ até 1 salário mínimo
# 2853                9.000000e+02   Mais de 1 até  2 salários mínimos
# 2854                5.270000e+02      Mais de ½ até 1 salário mínimo
# 2855                1.750000e+02      Mais de ¼ até ½ salário mínimo
# 2856                4.280000e+02      Mais de ½ até 1 salário mínimo
# 2857                2.210000e+02      Mais de ¼ até ½ salário mínimo
# 2859                1.510000e+02                Até ¼ salário mínimo
# 2860                6.500000e+02      Mais de ½ até 1 salário mínimo
# 2862                2.020000e+02      Mais de ¼ até ½ salário mínimo
# 2864                2.190000e+02      Mais de ¼ até ½ salário mínimo
# 2866                2.250000e+02      Mais de ¼ até ½ salário mínimo
# 2867                7.000000e+02   Mais de 1 até  2 salários mínimos
# 2868                1.500000e+03  Mais de  2 até  3 salários mínimos
# 2869                4.000000e+02      Mais de ½ até 1 salário mínimo
# 2870                2.120000e+02      Mais de ¼ até ½ salário mínimo
# 2872                3.700000e+02      Mais de ½ até 1 salário mínimo
# 2875                2.000000e+03  Mais de  2 até  3 salários mínimos
# 2876                0.000000e+00                      Sem rendimento
# 2877                7.000000e+02   Mais de 1 até  2 salários mínimos
# ...                          ...                                 ...
# 4360                1.500000e+03  Mais de  2 até  3 salários mínimos
# 4361                5.300000e+01                Até ¼ salário mínimo
# 4362                2.370000e+02      Mais de ¼ até ½ salário mínimo
# 4363                2.330000e+02      Mais de ¼ até ½ salário mínimo
# 4365                9.400000e+01                Até ¼ salário mínimo
# 4366                5.300000e+01                Até ¼ salário mínimo
# 4367                6.400000e+01                Até ¼ salário mínimo
# 4368                4.300000e+02      Mais de ½ até 1 salário mínimo
# 4369                7.510000e+02   Mais de 1 até  2 salários mínimos
# 4370                0.000000e+00                      Sem rendimento
# 4371                6.400000e+01                Até ¼ salário mínimo
# 4372                4.000000e+02      Mais de ½ até 1 salário mínimo
# 4373                0.000000e+00                      Sem rendimento
# 4374                1.500000e+02                Até ¼ salário mínimo
# 4375                9.500000e+02   Mais de 1 até  2 salários mínimos
# 4376                1.250000e+02                Até ¼ salário mínimo
# 4377                7.000000e+02   Mais de 1 até  2 salários mínimos
# 4379                1.000000e+12                      Sem declaração
# 4381                1.400000e+02                Até ¼ salário mínimo
# 4382                3.390000e+02      Mais de ¼ até ½ salário mínimo
# 4383                6.780000e+02      Mais de ½ até 1 salário mínimo
# 4385                2.250000e+02      Mais de ¼ até ½ salário mínimo
# 4386                0.000000e+00                      Sem rendimento
# 4387                3.290000e+02      Mais de ¼ até ½ salário mínimo
# 4388                3.280000e+02      Mais de ¼ até ½ salário mínimo
# 4389                2.690000e+02      Mais de ¼ até ½ salário mínimo
# 4390                4.390000e+02      Mais de ½ até 1 salário mínimo
# 4391                6.780000e+02      Mais de ½ até 1 salário mínimo
# 4392                2.590000e+02      Mais de ¼ até ½ salário mínimo
# 4393                1.400000e+02                Até ¼ salário mínimo
#
# [1232 rows x 7 columns]

# %% [markdown]
# # Moradia

# %%
Moradia_Internet2013=pd.crosstab( At2013.Moardia_Rural_Urbana, At2013.Acesso_Internet, margins=True, rownames=['Moardia (Área Rural ou Urbana)'], colnames=['Acesso Internet'], normalize=True)*100
Moradia_Internet2013=Moradia_Internet2013.round(decimals=1)
Moradia_Internet2013
# Out:
# Acesso Internet                                 Sim   Não    All
# Moardia (Área Rural ou Urbana)
# URBANA - Cidade ou vila, área urbanizada       30.1  40.7   70.8
# URBANA - Cidade ou vila, área não urbanizada    1.1   1.8    2.9
# RURAL - Aglomerado rural, isolado, povoado      0.6   2.9    3.5
# RURAL - Zona rural exclusive aglomerado rural   0.4  22.4   22.8
# All                                            32.2  67.8  100.0

# %%
plot = Moradia_Internet2013.plot(kind='bar')
plt.ylabel('Freq.Relativa (em %)')

# %%
Moradia_TV2013=pd.crosstab( At2013.Moardia_Rural_Urbana, At2013.Tem_TV, margins=True, rownames=['Moardia (Área Rural ou Urbana)'], colnames=['Tem TV'], normalize=True)*100
Moradia_TV2013=Moradia_TV2013.round(decimals=1)
Moradia_TV2013
# Out:
# Tem TV                                          Sim  Não    All
# Moardia (Área Rural ou Urbana)
# URBANA - Cidade ou vila, área urbanizada       68.7  2.1   70.8
# URBANA - Cidade ou vila, área não urbanizada    2.8  0.1    2.9
# RURAL - Aglomerado rural, isolado, povoado      3.1  0.4    3.5
# RURAL - Zona rural exclusive aglomerado rural  16.3  6.5   22.8
# All                                            90.9  9.1  100.0

# %%
plot = Moradia_TV2013.plot(kind='bar')
plt.ylabel('Freq.Relativa (em %)')

# %% [markdown]
# # Renda

# %%
ren2013 = At2013.Renda_per_capta_domiciliar
ren2013.describe()
# Out:
# count    1.232000e+03
# mean     2.353896e+10
# std      1.516692e+11
# min      0.000000e+00
# 25%      2.350000e+02
# 50%      4.895000e+02
# 75%      8.660000e+02
# max      1.000000e+12
# Name: Renda_per_capta_domiciliar, dtype: float64

# %% [markdown]
# Utilizando o conceito de amplitude interquartil, definimos que ualquer vaolor que não esteja no intervalo [Q1 - 1,5Q: Q3 + 1,5Q] sendo Q = Q3 - Q1, Q3 (Terceiro Quartil) e Q1 (Primeiro Quartil), ou seja [-711.5: 1812.5], seria extremo.

# %%
faixa3 = (0,937/4 ,937/2, 937, 1812.5)
ren2013rel = pd.cut(ren2013, faixa3, False)
print('Frequências relativas:')
ut3 = (ren2013rel.value_counts(sort=False, normalize=True)*100).round(decimals=1)
print(ut3,'\n')
# Out:
# Frequências relativas:
# [0.0, 234.25)      27.5
# [234.25, 468.5)    27.1
# [468.5, 937.0)     32.5
# [937.0, 1812.5)    12.9
# Name: Renda_per_capta_domiciliar, dtype: float64

# %%
fig = plt.figure(figsize=(11, 5))
plt.subplot(121)
plot = ren2013.plot.hist(bins=faixa3,title='Renda percapta domiciliar', figsize=(6, 6), normed=1, alpha=0.5)
plt.ylabel('Densidade')
plt.xlabel('renda (em reais)')

plt.subplot(122)
plot = ren2013.plot.hist(bins=faixa3, title='Renda percapta domiciliar', weights=zeros_like(ren2013)+1./ren2013.size*100, figsize=(6, 6), color = ('g'), alpha=0.5)
plt.ylabel('Frequência Relativa')
plt.xlabel('renda (em reais)')

plt.tight_layout()
plt.show()

# %%
renda_Internet2013=pd.crosstab( ren2013rel, At2015.Acesso_Internet, margins=True, rownames=['Renda per capta domiciliar (em salários mínimos)'], colnames=['Acesso Internet'], normalize=True)*100
renda_Internet2013=renda_Internet2013.round(decimals=1)
renda_Internet2013
# Out:
# Acesso Internet                                    Sim   Não    All
# Renda per capta domiciliar (em salários mínimos)
# [0.0, 234.25)                                     12.3  16.3   28.6
# [234.25, 468.5)                                   12.7  13.9   26.6
# [468.5, 937.0)                                    14.6  17.2   31.8
# [937.0, 1812.5)                                    6.2   6.8   13.0
# All                                               45.8  54.2  100.0

# %%
plot = renda_Internet2013.plot(kind='bar')
plt.ylabel('Freq.Relativa (em %)')

# %%
renda_TV2013=pd.crosstab( ren2013rel, At2013.Tem_TV, margins=True, rownames=['Renda per capta domiciliar (em salários mínimos)'], colnames=['Tem Tv'], normalize=True)*100
renda_TV2013=renda_TV2013.round(decimals=1)
renda_TV2013
# Out:
# Tem Tv                                             Sim  Não    All
# Renda per capta domiciliar (em salários mínimos)
# [0.0, 234.25)                                     22.6  4.9   27.5
# [234.25, 468.5)                                   24.5  2.5   27.1
# [468.5, 937.0)                                    30.8  1.7   32.5
# [937.0, 1812.5)                                   12.2  0.7   12.9
# All                                               90.1  9.9  100.0

# %%
plot = renda_TV2013.plot(kind='bar')
plt.ylabel('Freq.Relativa (em %)')

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# # Renda

# %%
fig = plt.figure(figsize=(11, 5))

plt.subplot(121)
plot = ren2013.plot.hist(bins=faixa3,title='Renda percapta domiciliar 2013', figsize=(6, 6), normed=1,color = ('g'), alpha=0.8)
plt.ylabel('Densidade')
plt.xlabel('renda (em reais)')

plt.subplot(122)
plot = ren2015.plot.hist(bins=faixa,title='Renda percapta domiciliar 2015', figsize=(6, 6),color = ('b'), normed=1, alpha=0.8)
plt.ylabel('Densidade')
plt.xlabel('renda (em reais)')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(11, 5))
plt.subplot(121)
plot = ren2014.plot.hist(bins=faixa2,title='Renda percapta domiciliar 2014', figsize=(6, 6),color = ('b'), normed=1, alpha=0.8)
plt.ylabel('Densidade')
plt.xlabel('renda (em reais)')


plt.subplot(122)
plot = ren2015.plot.hist(bins=faixa,title='Renda percapta domiciliar 2015', figsize=(6, 6), normed=1,color = ('g'), alpha=0.8)
plt.ylabel('Densidade')
plt.xlabel('renda (em reais)')



plt.tight_layout()
plt.show()

# %% [markdown]
# Descreva aqui suas conclusões!
