# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# Pedro Villas Bôas Dias -
# Enegnharia 2A

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# Qual o acesso à internet e a televisão das pessoas comparando suas rendas e a área em que moram?

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\pedro\OneDrive\Documentos\1)INSPER\Semestres\2 SEMESTRE\CIÊNCIAS DOS DADOS\Projeto1\Projeto1-CD

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')

#Se usar o arquivo compactado como está no dropbox púbico
dados2015 = pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')
dados2014 = pd.read_csv('DOM2014csv.zip', compression='zip', header=0, sep=',', quotechar='"')
dados2013 = pd.read_csv('DOM2013csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
At2015 = dados2015.loc[dados2015.UF== 12,['UF','V0219', 'V0226', 'V0227', 'V02322','V4105', 'V4622',]]

# %%
At2015.columns = ["Estado","Fonte_de_Iluminação","TV_em_Cores", "TV_em_Preto_Branco", "Acesso_Internet", "Moardia_Rural_Urbana", "Renda_per_capta_domiciliar"]

# %%
At2015.columns
# Out:
# Index(['Estado', 'Fonte_de_Iluminação', 'TV_em_Cores', 'TV_em_Preto_Branco',
#        'Acesso_Internet', 'Moardia_Rural_Urbana',
#        'Renda_per_capta_domiciliar'],
#       dtype='object')

# %%
At2015.Estado = At2015.Estado.astype('category')
At2015.Fonte_de_Iluminação = At2015.Fonte_de_Iluminação.astype('category')
At2015.TV_em_Cores = At2015.TV_em_Cores.astype('category')
At2015.TV_em_Preto_Branco = At2015.TV_em_Preto_Branco.astype('category')
At2015.Acesso_Internet = At2015.Acesso_Internet.astype('category')
At2015.Moardia_Rural_Urbana = At2015.Moardia_Rural_Urbana.astype('category')
At2015.Renda_per_capta_domiciliar = At2015.Renda_per_capta_domiciliar.astype('category')

# %%
At2015.Estado.cat.categories
# Out:
# Int64Index([12], dtype='int64')

# %%
At2015.Estado.cat.categories = (["Acre"])

At2015.Renda_per_capta_domiciliar.cat.categories  = (["Sem rendimento", "Até ¼ salário mínimo", "Mais de ¼ até ½ salário mínimo", "Mais de ½ até 1 salário mínimo", "Mais de 1 até  2 salários mínimos",\
"Mais de  2 até  3 salários mínimos", "Mais de 3 até 5 salários mínimos", "Mais de 5 salários mínimos", "Sem declaração"])

At2015.Fonte_de_Iluminação.cat.categories = (["Elétrica (de rede, gerador, solar)","Óleo, querosene ou gás de botijão", "Outra forma"])

At2015.TV_em_Cores.cat.categories = (["Sim","Não"])

At2015.TV_em_Preto_Branco.cat.categories = (["Sim","Não"])

At2015.Acesso_Internet.cat.categories = (["Sim","Não"])

At2015.Moardia_Rural_Urbana.cat.categories = (["URBANA - Cidade ou vila, área urbanizada","URBANA - Cidade ou vila, área não urbanizada",\
"RURAL - Aglomerado rural, isolado, povoado", "RURAL - Zona rural exclusive aglomerado rural"])

# %%
At2015 = At2015.dropna()

# %%
At2015
# Out:
#      Estado                 Fonte_de_Iluminação TV_em_Cores  \
# 2841   Acre  Elétrica (de rede, gerador, solar)         Não
# 2849   Acre  Elétrica (de rede, gerador, solar)         Não
# 2860   Acre  Elétrica (de rede, gerador, solar)         Não
# 2867   Acre  Elétrica (de rede, gerador, solar)         Não
# 2886   Acre  Elétrica (de rede, gerador, solar)         Não
# 2887   Acre  Elétrica (de rede, gerador, solar)         Não
# 2916   Acre  Elétrica (de rede, gerador, solar)         Não
# 2921   Acre  Elétrica (de rede, gerador, solar)         Não
# 2924   Acre  Elétrica (de rede, gerador, solar)         Não
# 2945   Acre  Elétrica (de rede, gerador, solar)         Não
# 2951   Acre  Elétrica (de rede, gerador, solar)         Não
# 2963   Acre  Elétrica (de rede, gerador, solar)         Não
# 2973   Acre  Elétrica (de rede, gerador, solar)         Não
# 3007   Acre  Elétrica (de rede, gerador, solar)         Não
# 3011   Acre  Elétrica (de rede, gerador, solar)         Não
# 3013   Acre  Elétrica (de rede, gerador, solar)         Não
# 3017   Acre  Elétrica (de rede, gerador, solar)         Não
# 3033   Acre  Elétrica (de rede, gerador, solar)         Não
# 3038   Acre  Elétrica (de rede, gerador, solar)         Não
# 3047   Acre  Elétrica (de rede, gerador, solar)         Não
# 3056   Acre  Elétrica (de rede, gerador, solar)         Não
# 3072   Acre  Elétrica (de rede, gerador, solar)         Não
# 3074   Acre  Elétrica (de rede, gerador, solar)         Não
# 3081   Acre  Elétrica (de rede, gerador, solar)         Não
# 3112   Acre   Óleo, querosene ou gás de botijão         Não
# 3114   Acre  Elétrica (de rede, gerador, solar)         Não
# 3143   Acre  Elétrica (de rede, gerador, solar)         Não
# 3169   Acre  Elétrica (de rede, gerador, solar)         Não
# 3176   Acre   Óleo, querosene ou gás de botijão         Não
# 3177   Acre   Óleo, querosene ou gás de botijão         Não
# ...     ...                                 ...         ...
# 4226   Acre   Óleo, querosene ou gás de botijão         Não
# 4232   Acre  Elétrica (de rede, gerador, solar)         Não
# 4236   Acre   Óleo, querosene ou gás de botijão         Não
# 4237   Acre   Óleo, querosene ou gás de botijão         Não
# 4238   Acre  Elétrica (de rede, gerador, solar)         Não
# 4239   Acre   Óleo, querosene ou gás de botijão         Não
# 4242   Acre   Óleo, querosene ou gás de botijão         Não
# 4245   Acre  Elétrica (de rede, gerador, solar)         Não
# 4309   Acre  Elétrica (de rede, gerador, solar)         Não
# 4329   Acre  Elétrica (de rede, gerador, solar)         Não
# 4359   Acre   Óleo, querosene ou gás de botijão         Não
# 4360   Acre   Óleo, querosene ou gás de botijão         Não
# 4361   Acre                         Outra forma         Não
# 4363   Acre   Óleo, querosene ou gás de botijão         Não
# 4366   Acre                         Outra forma         Não
# 4369   Acre  Elétrica (de rede, gerador, solar)         Não
# 4370   Acre   Óleo, querosene ou gás de botijão         Não
# 4372   Acre   Óleo, querosene ou gás de botijão         Não
# 4373   Acre  Elétrica (de rede, gerador, solar)         Não
# 4379   Acre  Elétrica (de rede, gerador, solar)         Não
# 4391   Acre  Elétrica (de rede, gerador, solar)         Não
# 4412   Acre                         Outra forma         Não
# 4413   Acre   Óleo, querosene ou gás de botijão         Não
# 4419   Acre  Elétrica (de rede, gerador, solar)         Não
# 4431   Acre  Elétrica (de rede, gerador, solar)         Não
# 4436   Acre  Elétrica (de rede, gerador, solar)         Não
# 4437   Acre  Elétrica (de rede, gerador, solar)         Não
# 4441   Acre  Elétrica (de rede, gerador, solar)         Não
# 4454   Acre  Elétrica (de rede, gerador, solar)         Não
# 4463   Acre  Elétrica (de rede, gerador, solar)         Não
#
#      TV_em_Preto_Branco Acesso_Internet  \
# 2841                Não             Não
# 2849                Não             Não
# 2860                Não             Não
# 2867                Não             Sim
# 2886                Não             Não
# 2887                Não             Não
# 2916                Não             Não
# 2921                Não             Sim
# 2924                Não             Sim
# 2945                Não             Não
# 2951                Não             Não
# 2963                Não             Não
# 2973                Não             Não
# 3007                Não             Não
# 3011                Não             Não
# 3013                Sim             Não
# 3017                Não             Não
# 3033                Não             Não
# 3038                Não             Não
# 3047                Não             Não
# 3056                Não             Não
# 3072                Não             Não
# 3074                Não             Não
# 3081                Não             Não
# 3112                Não             Não
# 3114                Não             Não
# 3143                Não             Não
# 3169                Não             Não
# 3176                Não             Não
# 3177                Não             Não
# ...                 ...             ...
# 4226                Não             Não
# 4232                Não             Não
# 4236                Não             Não
# 4237                Não             Não
# 4238                Não             Não
# 4239                Não             Não
# 4242                Não             Não
# 4245                Não             Não
# 4309                Não             Não
# 4329                Não             Não
# 4359                Não             Não
# 4360                Não             Não
# 4361                Não             Não
# 4363                Não             Não
# 4366                Não             Não
# 4369                Não             Não
# 4370                Não             Não
# 4372                Não             Não
# 4373                Não             Não
# 4379                Não             Não
# 4391                Não             Sim
# 4412                Não             Não
# 4413                Não             Não
# 4419                Não             Não
# 4431                Não             Não
# 4436                Não             Não
# 4437                Não             Não
# 4441                Não             Sim
# 4454                Não             Não
# 4463                Não             Não
#
#                                Moardia_Rural_Urbana  \
# 2841       URBANA - Cidade ou vila, área urbanizada
# 2849       URBANA - Cidade ou vila, área urbanizada
# 2860       URBANA - Cidade ou vila, área urbanizada
# 2867       URBANA - Cidade ou vila, área urbanizada
# 2886  RURAL - Zona rural exclusive aglomerado rural
# 2887  RURAL - Zona rural exclusive aglomerado rural
# 2916       URBANA - Cidade ou vila, área urbanizada
# 2921       URBANA - Cidade ou vila, área urbanizada
# 2924       URBANA - Cidade ou vila, área urbanizada
# 2945       URBANA - Cidade ou vila, área urbanizada
# 2951       URBANA - Cidade ou vila, área urbanizada
# 2963       URBANA - Cidade ou vila, área urbanizada
# 2973       URBANA - Cidade ou vila, área urbanizada
# 3007       URBANA - Cidade ou vila, área urbanizada
# 3011  RURAL - Zona rural exclusive aglomerado rural
# 3013  RURAL - Zona rural exclusive aglomerado rural
# 3017  RURAL - Zona rural exclusive aglomerado rural
# 3033       URBANA - Cidade ou vila, área urbanizada
# 3038  RURAL - Zona rural exclusive aglomerado rural
# 3047  RURAL - Zona rural exclusive aglomerado rural
# 3056       URBANA - Cidade ou vila, área urbanizada
# 3072       URBANA - Cidade ou vila, área urbanizada
# 3074       URBANA - Cidade ou vila, área urbanizada
# 3081       URBANA - Cidade ou vila, área urbanizada
# 3112  RURAL - Zona rural exclusive aglomerado rural
# 3114  RURAL - Zona rural exclusive aglomerado rural
# 3143  RURAL - Zona rural exclusive aglomerado rural
# 3169       URBANA - Cidade ou vila, área urbanizada
# 3176  RURAL - Zona rural exclusive aglomerado rural
# 3177  RURAL - Zona rural exclusive aglomerado rural
# ...                                             ...
# 4226  RURAL - Zona rural exclusive aglomerado rural
# 4232       URBANA - Cidade ou vila, área urbanizada
# 4236  RURAL - Zona rural exclusive aglomerado rural
# 4237  RURAL - Zona rural exclusive aglomerado rural
# 4238  RURAL - Zona rural exclusive aglomerado rural
# 4239  RURAL - Zona rural exclusive aglomerado rural
# 4242  RURAL - Zona rural exclusive aglomerado rural
# 4245  RURAL - Zona rural exclusive aglomerado rural
# 4309       URBANA - Cidade ou vila, área urbanizada
# 4329   URBANA - Cidade ou vila, área não urbanizada
# 4359  RURAL - Zona rural exclusive aglomerado rural
# 4360  RURAL - Zona rural exclusive aglomerado rural
# 4361  RURAL - Zona rural exclusive aglomerado rural
# 4363  RURAL - Zona rural exclusive aglomerado rural
# 4366  RURAL - Zona rural exclusive aglomerado rural
# 4369  RURAL - Zona rural exclusive aglomerado rural
# 4370  RURAL - Zona rural exclusive aglomerado rural
# 4372  RURAL - Zona rural exclusive aglomerado rural
# 4373  RURAL - Zona rural exclusive aglomerado rural
# 4379       URBANA - Cidade ou vila, área urbanizada
# 4391       URBANA - Cidade ou vila, área urbanizada
# 4412  RURAL - Zona rural exclusive aglomerado rural
# 4413  RURAL - Zona rural exclusive aglomerado rural
# 4419  RURAL - Zona rural exclusive aglomerado rural
# 4431     RURAL - Aglomerado rural, isolado, povoado
# 4436     RURAL - Aglomerado rural, isolado, povoado
# 4437     RURAL - Aglomerado rural, isolado, povoado
# 4441     RURAL - Aglomerado rural, isolado, povoado
# 4454  RURAL - Zona rural exclusive aglomerado rural
# 4463     RURAL - Aglomerado rural, isolado, povoado
#
#               Renda_per_capta_domiciliar
# 2841   Mais de 1 até  2 salários mínimos
# 2849      Mais de ¼ até ½ salário mínimo
# 2860      Mais de ½ até 1 salário mínimo
# 2867                Até ¼ salário mínimo
# 2886   Mais de 1 até  2 salários mínimos
# 2887                Até ¼ salário mínimo
# 2916      Mais de ¼ até ½ salário mínimo
# 2921   Mais de 1 até  2 salários mínimos
# 2924      Mais de ½ até 1 salário mínimo
# 2945                      Sem rendimento
# 2951   Mais de 1 até  2 salários mínimos
# 2963      Mais de ¼ até ½ salário mínimo
# 2973      Mais de ½ até 1 salário mínimo
# 3007                Até ¼ salário mínimo
# 3011      Mais de ½ até 1 salário mínimo
# 3013                Até ¼ salário mínimo
# 3017                Até ¼ salário mínimo
# 3033      Mais de ¼ até ½ salário mínimo
# 3038                Até ¼ salário mínimo
# 3047      Mais de ¼ até ½ salário mínimo
# 3056      Mais de ½ até 1 salário mínimo
# 3072      Mais de ¼ até ½ salário mínimo
# 3074      Mais de ½ até 1 salário mínimo
# 3081      Mais de ¼ até ½ salário mínimo
# 3112      Mais de ¼ até ½ salário mínimo
# 3114   Mais de 1 até  2 salários mínimos
# 3143   Mais de 1 até  2 salários mínimos
# 3169      Mais de ¼ até ½ salário mínimo
# 3176                Até ¼ salário mínimo
# 3177      Mais de ¼ até ½ salário mínimo
# ...                                  ...
# 4226                Até ¼ salário mínimo
# 4232                Até ¼ salário mínimo
# 4236                Até ¼ salário mínimo
# 4237      Mais de ½ até 1 salário mínimo
# 4238                Até ¼ salário mínimo
# 4239                Até ¼ salário mínimo
# 4242                Até ¼ salário mínimo
# 4245      Mais de ½ até 1 salário mínimo
# 4309      Mais de ½ até 1 salário mínimo
# 4329   Mais de 1 até  2 salários mínimos
# 4359      Mais de ½ até 1 salário mínimo
# 4360      Mais de ¼ até ½ salário mínimo
# 4361                Até ¼ salário mínimo
# 4363                Até ¼ salário mínimo
# 4366                Até ¼ salário mínimo
# 4369  Mais de  2 até  3 salários mínimos
# 4370      Mais de ½ até 1 salário mínimo
# 4372      Mais de ½ até 1 salário mínimo
# 4373      Mais de ¼ até ½ salário mínimo
# 4379   Mais de 1 até  2 salários mínimos
# 4391      Mais de ¼ até ½ salário mínimo
# 4412      Mais de ½ até 1 salário mínimo
# 4413   Mais de 1 até  2 salários mínimos
# 4419      Mais de ½ até 1 salário mínimo
# 4431      Mais de ¼ até ½ salário mínimo
# 4436      Mais de ½ até 1 salário mínimo
# 4437   Mais de 1 até  2 salários mínimos
# 4441      Mais de ½ até 1 salário mínimo
# 4454      Mais de ¼ até ½ salário mínimo
# 4463      Mais de ½ até 1 salário mínimo
#
# [125 rows x 7 columns]

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
